# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Tools for Data Science Peer Graded Assignment

# %% [markdown]
#  ##### This notebook contains the exercises for Peer graded assignment of the above mentioned course

# %% [markdown]
# **Objectives**
# * List popular languages used in Data Science
# * List some libraries used for Data Science
# * List some data science tools
# * How to make and run a code cell
# * How to do various formatting in markdown cells

# %% [markdown]
# **Data Science Languages**
# 1. Python
# 2. R
# 3. SQL
# 4. SCALA
# 5. Ruby
# 6. Java
# 7. JavaScript

# %% [markdown]
# **Data Science libraries:**
# 1. NumPy
# 2. Pandas
# 3. Scikit
# 4. MatplotLib
# 5. Seaborn
# 6. Plotly
# 7. TensorFlow
# 8. PyTorch

# %% [markdown]
# **Data Science Tools**
#
# | Data Science Tools |
# | :----------------- |
# | JupyterLab         |
# | RStudio            |
# | Apache Spark       |
# | Apache zeppelin    |

# %% [markdown]
# **Arithmetic expression examples**
# * Addition: 1 + 1 = 2
# * Subtraction: 10 - 3 = 7
# * Multiplication: 5 * 4 = 20
# * Division: 35/7 = 5

# %%
# This a simple arithmetic expression to mutiply then add integers
(34*2) + 232
# Out:
# 300

# %%
# This will convert 540 minutes to hours by diving by 60
minutes = 540
hours = 540/60
hours
# Out:
# 9.0

# %% [markdown]
# #### Author's name
# Gowtham Balaji R
